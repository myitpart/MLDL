# %%
# ws04
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls '/content/drive/MyDrive/Colab Notebooks/datasets'

# %% [markdown]
# # Dataset

# %%
fileuri = '/content/drive/MyDrive/Colab Notebooks/datasets/advertising.csv'

df = pd.read_csv(fileuri, usecols=['TV','Sales'])

df.head()

# %%
df.describe()

# %%
df.shape

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
x = df.TV.values.reshape(-1,1)
y = df.Sales.values

x[:5]

# %%
# prompt: display first 10 rows

print(df.head(10))

# %%
y[:10]

# %%
plt.scatter(x, y)
plt.show()

# %%
y[:5]

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error #, r2_score

# %%
model = LinearRegression()
model.fit(x, y)

# %%
model.coef_ , model.intercept_  # m and b

# %%
model.score(x, y)

# %%
y_predict = model.predict(x)
mean_squared_error(y, y_predict)

# %%
mean_absolute_error(y, y_predict)

# %% [markdown]
# # Prediction

# %%
x_input = 210
x_input = np.array(x_input).reshape(-1, 1)

y_predict = model.predict(x_input)
print('predicted sales=', y_predict)

# %%
# sns.set_style('darkgrid')

sns.lmplot(x='TV', y='Sales', data=df)
plt.show()

# %%
x_input = [[300],
           [500],
           [1000]]

y_predict = model.predict(x_input)
y_predict

# %% [markdown]
# # ws05

# %%
# ws05
df = pd.read_csv(fileuri, index_col=0)
df.head()

# %%
sns.pairplot(df, x_vars=['TV','Radio','Newspaper'], y_vars='Sales',
             height=3.5) #,kind='reg'

plt.show()

# %%
g = sns.pairplot(df)
g.fig.set_size_inches(6, 6)

# %%
feature_cols = ['TV','Radio','Newspaper']
X = df[feature_cols]
y = df.Sales

# %%
model = LinearRegression()
model.fit(X, y)

# %%
print(model.coef_)
print(model.intercept_)  # m and b

# %%
list(zip(feature_cols, model.coef_))

# %%
model.score(X, y)

# %%
x_input = [[300, 0, 0],
           [0, 300, 0],
           [0, 0, 300],
           [100, 200, 200],
           [100, 200, 0]]
y_predict = model.predict(x_input)

y_predict
